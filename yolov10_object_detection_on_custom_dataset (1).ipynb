# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install -q git+https://github.com/THU-MIG/yolov10.git

from IPython import display
display.clear_output()

# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt
# !wget -P {HOME}/weights -q https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt
# !ls -lh {HOME}/weights
# Out:
# total 43M
# -rw-r--r-- 1 root root 11M May 23 09:38 yolov10n.pt
# -rw-r--r-- 1 root root 32M May 23 09:38 yolov10s.pt

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %%
# %cd {HOME}
# !yolo task=detect mode=predict conf=0.25 save=True model={HOME}/weights/yolov10s.pt source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10s summary (fused): 293 layers, 8096880 parameters, 86880 gradients, 24.8 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 97.5MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 0, 1 2, 2 16s, 1 24, 135.8ms
# Speed: 12.5ms preprocess, 135.8ms inference, 383.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'	'My Drive'	     waterbottleconveyorbelt.zip
#  data.zip		 rules.zip	     yolov10-object-tracking-counting-main.zip
#  dist			 testgooglemachine   yolov4-tiny
#  dlss_snowymoon.io.zip	 vehiclecount

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/rules.zip
# Out:
# /content/datasets
# Archive:  /content/gdrive/MyDrive/rules.zip
#    creating: rules/
#    creating: rules/images/
#    creating: rules/images/training/
#  extracting: rules/images/training/classes.txt
#   inflating: rules/images/training/img_0.jpg
#   inflating: rules/images/training/img_0.txt
#   inflating: rules/images/training/img_1.jpg
#   inflating: rules/images/training/img_1.txt
#   inflating: rules/images/training/img_10.jpg
#   inflating: rules/images/training/img_10.txt
#   inflating: rules/images/training/img_100.jpg
#   inflating: rules/images/training/img_100.txt
#   inflating: rules/images/training/img_101.jpg
#   inflating: rules/images/training/img_101.txt
#   inflating: rules/images/training/img_102.jpg
#   inflating: rules/images/training/img_102.txt
#   inflating: rules/images/training/img_103.jpg
#   inflating: rules/images/training/img_103.txt
#   inflating: rules/images/training/img_104.jpg
#   inflating: rules/images/training/img_104.txt
# ...

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov10s.pt data=/content/datasets/rules/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.2.42 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
